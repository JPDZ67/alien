# %%
import pandas as pd

# %%
scrubbed_df = pd.read_csv('../raw_data/scrubbed.csv')
new_data_df = pd.read_csv('../raw_data/ufo.csv')
# Out:
# /home/verabrizola/.pyenv/versions/3.8.6/envs/alien/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (5,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
scrubbed_df.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
new_data_df.head()
# Out:
#         Datetime            City State   Shape    Duration  \
# 0  4/23/21 06:30      Blackshear    GA  Circle   9 minutes
# 1  4/23/21 06:00  Mechanicsville    VA  Circle     Seconds
# 2  4/23/21 06:00      Vero Beach    FL   Light   5 minutes
# 3  4/23/21 05:59   St. Augustine    FL   Light   3 minutes
# 4  4/23/21 05:58          Durham    NC    Cone  >5 minutes
#
#                                              Summary   Posted
# 0  Very strange   ((NUFORC Note:  Rocket launch f...  4/23/21
# 1  Ball in the sky   ((NUFORC Note:  Rocket launc...  4/23/21
# 2  I was driving and saw something strange in the...  4/23/21
# 3  2 extremely bright lights appeared over east c...  4/23/21
# 4  A cone of light coming from the sky unlike any...  4/23/21

# %%
scrubbed_df.drop(columns=['latitude', 'longitude ', 'date posted', 'duration (hours/min)', 'comments'], inplace=True)
new_data_df.drop(columns=['Posted', 'Summary'], inplace=True)

# %%
new_data_df.rename(
    columns={'Datetime': 'datetime', 
             'City': 'city', 
             'State': 'state', 
             'Shape': 'shape', 
             'Duration': 'duration (seconds)', 
             'Summary': 'summary'},
    inplace=True)

# %%
scrubbed_df.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds)
# 0               2700
# 1               7200
# 2                 20
# 3                 20
# 4                900

# %%
new_data_df.head()
# Out:
#         datetime            city state   shape duration (seconds)
# 0  4/23/21 06:30      Blackshear    GA  Circle          9 minutes
# 1  4/23/21 06:00  Mechanicsville    VA  Circle            Seconds
# 2  4/23/21 06:00      Vero Beach    FL   Light          5 minutes
# 3  4/23/21 05:59   St. Augustine    FL   Light          3 minutes
# 4  4/23/21 05:58          Durham    NC    Cone         >5 minutes

# %%
# All NaN values are cities outside the us or missing the datetime
new_data_df.dropna(inplace=True)
scrubbed_df.dropna(inplace=True)

# %%
new_data_df
# Out:
#                datetime            city state     shape  \
# 0         4/23/21 06:30      Blackshear    GA    Circle
# 1         4/23/21 06:00  Mechanicsville    VA    Circle
# 2         4/23/21 06:00      Vero Beach    FL     Light
# 3         4/23/21 05:59   St. Augustine    FL     Light
# 4         4/23/21 05:58          Durham    NC      Cone
# ...                 ...             ...   ...       ...
# 97165             00:04         Alabama    AL   Diamond
# 97166             00:00   New York City    NY    Circle
# 97167  5/20/20014 00:00         Atlanta    GA   Unknown
# 97168   1947-2008 00:00    Maple Valley    WA  Changing
# 97170                --        Monument    CO  Changing
#
#               duration (seconds)
# 0                      9 minutes
# 1                        Seconds
# 2                      5 minutes
# 3                      3 minutes
# 4                     >5 minutes
# ...                          ...
# 97165                 60 seconds
# 97166  20 seconds I think I lost
# 97167                  2 seconds
# 97168                    4 years
# 97170               8-12 MINUTES
#
# [86327 rows x 5 columns]

# %%
scrubbed_df['datetime'] = scrubbed_df['datetime'].apply(lambda x: x.replace('24:','0:'))
scrubbed_df['datetime'] = pd.to_datetime(scrubbed_df['datetime'], errors='coerce')
scrubbed_df.sort_values('datetime', axis=0, ascending=True, inplace=True)

# %%
latest_date = scrubbed_df['datetime'].max()

new_data_df['datetime'] = new_data_df['datetime'].apply(lambda x: x.replace('24:','0:'))
new_data_df['datetime'] = pd.to_datetime(new_data_df['datetime'], errors='coerce')
new_data_df.sort_values('datetime', axis=0, ascending=True, inplace=True)


new_data_df = new_data_df[new_data_df['datetime'] > latest_date]

# %%
from datetime import datetime

today = datetime.today()

new_data_df = new_data_df[new_data_df['datetime'] < today]

# %%
new_data_df
# Out:
#                  datetime            city state      shape duration (seconds)
# 41803 2014-05-08 01:00:00  Jeffersonville    IN  Formation           1 minute
# 41802 2014-05-08 11:30:00          Tucson    AZ     Circle         30 minutes
# 41801 2014-05-08 16:00:00      Lake Villa    IL       Disk         60 seconds
# 41799 2014-05-08 17:00:00        Franklin    IN       Disk      brief seconds
# 41800 2014-05-08 17:00:00          Dublin    OH   Cylinder         20 seconds
# ...                   ...             ...   ...        ...                ...
# 97131 2021-06-01 14:00:00  Salt Lake City    UT       Disk         20 seconds
# 97129 2021-06-01 16:00:00           Nampa    ID      Other          5 minutes
# 97128 2021-06-01 17:00:00    Philadelphia    PA     Circle         10 minutes
# 97125 2021-06-01 17:55:00       Englewood    FL  Formation          2 minutes
# 97121 2021-06-01 19:00:00        Palm Bay    FL     Circle         10 minutes
#
# [37303 rows x 5 columns]

# %%
new_data_df['datetime'].isna().sum()
# Out:
# 0

# %%
def str_int(string):
    for s in string.split():
        if 'minutes' or 'minute' in string.split():
            return int(int(s) * 60) if s.isdigit() else None
        elif 'seconds' or 'second' in string.split():
            return int(s) if s.isdigit() else None
        elif 'hours' or 'hour' in string.split():
            return int(int(s) * 3600) if s.isdigit() else None
        else:
            return None

new_data_df['duration (seconds)'] = new_data_df['duration (seconds)'].apply(str_int)

# %%
new_data_df
# Out:
#                  datetime            city state      shape  duration (seconds)
# 41803 2014-05-08 01:00:00  Jeffersonville    IN  Formation                60.0
# 41802 2014-05-08 11:30:00          Tucson    AZ     Circle              1800.0
# 41801 2014-05-08 16:00:00      Lake Villa    IL       Disk              3600.0
# 41799 2014-05-08 17:00:00        Franklin    IN       Disk                 NaN
# 41800 2014-05-08 17:00:00          Dublin    OH   Cylinder              1200.0
# ...                   ...             ...   ...        ...                 ...
# 97131 2021-06-01 14:00:00  Salt Lake City    UT       Disk              1200.0
# 97129 2021-06-01 16:00:00           Nampa    ID      Other               300.0
# 97128 2021-06-01 17:00:00    Philadelphia    PA     Circle               600.0
# 97125 2021-06-01 17:55:00       Englewood    FL  Formation               120.0
# 97121 2021-06-01 19:00:00        Palm Bay    FL     Circle               600.0
#
# [37303 rows x 5 columns]

# %%
scrubbed_df['duration (seconds)'] = scrubbed_df['duration (seconds)'].astype('float')
scrubbed_df.dtypes
# Out:
# datetime              datetime64[ns]
# city                          object
# state                         object
# country                       object
# shape                         object
# duration (seconds)           float64
# dtype: object

# %%
scrubbed_df = scrubbed_df[scrubbed_df['country'] == 'us']
scrubbed_df.drop(columns=['country'], inplace=True)

# %%
master_df = pd.concat([scrubbed_df, new_data_df], ignore_index=True)
master_df['city'] = master_df['city'].apply(lambda x: x.lower())
master_df['state'] = master_df['state'].apply(lambda x: x.lower())

master_df
# Out:
#                   datetime                         city state      shape  \
# 0      1910-01-01 00:00:00            kirksville (near)    mo       disk
# 1      1910-06-01 15:00:00                  wills point    tx      cigar
# 2      1920-06-11 21:00:00                       cicero    in    unknown
# 3      1925-12-28 18:00:00  atkinson (6 miles north of)    il       disk
# 4      1929-07-05 14:00:00         buchanan  (or burns)    or       disk
# ...                    ...                          ...   ...        ...
# 100859 2021-06-01 14:00:00               salt lake city    ut       Disk
# 100860 2021-06-01 16:00:00                        nampa    id      Other
# 100861 2021-06-01 17:00:00                 philadelphia    pa     Circle
# 100862 2021-06-01 17:55:00                    englewood    fl  Formation
# 100863 2021-06-01 19:00:00                     palm bay    fl     Circle
#
#         duration (seconds)
# 0                    120.0
# 1                    120.0
# 2                     60.0
# 3                     60.0
# 4                     60.0
# ...                    ...
# 100859              1200.0
# 100860               300.0
# 100861               600.0
# 100862               120.0
# 100863               600.0
#
# [100864 rows x 5 columns]

# %%
master_df.to_csv('../raw_data/sightings.csv', header=True, index=False)

# %%
uscities_data_df = pd.read_csv('../raw_data/uscities.csv')

# %%
uscities_data_df = uscities_data_df[['state_name','population','military', 'city']]

# %%
uscities_data_df = uscities_data_df.groupby(by =['state_name']).agg({'population':'sum', 'military':'sum', 'city':'count'}).reset_index()

# %%
uscities_data_df.head()
# Out:
#    state_name  population  military  city
# 0     Alabama     4392298         2   581
# 1      Alaska      739126         3   326
# 2     Arizona     9953669         0   427
# 3    Arkansas     2665795         0   536
# 4  California    59652083        10  1470

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
uscities_data_df['state'] = uscities_data_df['state_name'].map(us_state_abbrev)

# %%
uscities_data_df['state']= uscities_data_df.state.str.lower()

# %%
uscities_data_df
# Out:
#               state_name  population  military  city state
# 0                Alabama     4392298         2   581    al
# 1                 Alaska      739126         3   326    ak
# 2                Arizona     9953669         0   427    az
# 3               Arkansas     2665795         0   536    ar
# 4             California    59652083        10  1470    ca
# 5               Colorado     7734597         2   448    co
# 6            Connecticut     4074019         1   110    ct
# 7               Delaware      565804         1    77    de
# 8   District of Columbia     5379184         0     1    dc
# 9                Florida    31031088         4   911    fl
# 10               Georgia    11192163         4   617    ga
# 11                Hawaii     1826327         5   149    hi
# 12                 Idaho     1704042         1   226    id
# 13              Illinois    18104498         1  1362    il
# 14               Indiana     6236667         1   677    in
# 15                  Iowa     3193169         0  1003    ia
# 16                Kansas     2595209         2   669    ks
# 17              Kentucky     3307905         2   538    ky
# 18             Louisiana     4845764         2   474    la
# 19                 Maine      624328         0    41    me
# 20              Maryland     6840820         6   510    md
# 21         Massachusetts     9103538         1   139    ma
# 22              Michigan    10403850         0   689    mi
# 23             Minnesota     7402427         0   896    mn
# 24           Mississippi     2093005         2   361    ms
# 25              Missouri     7474758         2  1020    mo
# 26               Montana      842286         1   360    mt
# 27              Nebraska     1910641         1   576    ne
# 28                Nevada     4548072         2   125    nv
# 29         New Hampshire      813191         0    38    nh
# 30            New Jersey     5549930         2   508    nj
# 31            New Mexico     2118537         3   425    nm
# 32              New York    36249123         2   880    ny
# 33        North Carolina     9441066         0   733    nc
# 34          North Dakota      735625         2   397    nd
# 35                  Ohio    13813630         1  1202    oh
# 36              Oklahoma     3727497         0   732    ok
# 37                Oregon     5311863         0   373    or
# 38          Pennsylvania    15443773         0  1649    pa
# 39           Puerto Rico     1854657         0   243    pr
# 40          Rhode Island     1650022         1    32    ri
# 41        South Carolina     4625071         0   394    sc
# 42          South Dakota      698307         0   382    sd
# 43             Tennessee     6172183         0   427    tn
# 44                 Texas    33717239         5  1679    tx
# 45                  Utah     4969594         1   322    ut
# 46               Vermont      244194         0    48    vt
# 47              Virginia     8272237         5   586    va
# 48            Washington    10455744         6   609    wa
# 49         West Virginia     1347403         0   401    wv
# 50             Wisconsin     5981538         0   773    wi
# 51               Wyoming      490393         1   186    wy

# %%
master_state_df = master_df.merge(uscities_data_df, on='state', how = 'left')

# %%
master_state_df.dropna(inplace = True)

# %%
master_state_df.rename(columns=({'city_x':'city', 'city_y':'state_cities', 'military':'state_military_bases', 'population':'state_population'}), inplace = True)

# %%
master_state_df['day'] = master_state_df['datetime'].apply(lambda x: x.strftime("%Y-%m-%d"))
master_state_df['month'] = master_state_df['datetime'].apply(lambda x: x.strftime("%Y-%m"))
master_state_df['month_number'] = master_state_df['datetime'].apply(lambda x: int(x.month))
master_state_df['year_number'] = master_state_df['datetime'].apply(lambda x: int(x.year))

# %%
seasons = ['winter','winter','spring','spring','spring','summer','summer','summer','autumn','autumn','autumn','winter']
month_to_season = dict(zip(range(1,13), seasons))
master_state_df['season'] = master_state_df.month_number.map(month_to_season)
master_state_df['year_season'] = master_state_df['year_number'].astype(str)+'-'+master_state_df['season']

# %%
master_state_df.to_csv('../raw_data/state_sightings.csv', header=True, index=False)
master_state_df.head()
# Out:
#              datetime                         city state    shape  \
# 0 1910-01-01 00:00:00            kirksville (near)    mo     disk
# 1 1910-06-01 15:00:00                  wills point    tx    cigar
# 2 1920-06-11 21:00:00                       cicero    in  unknown
# 3 1925-12-28 18:00:00  atkinson (6 miles north of)    il     disk
# 4 1929-07-05 14:00:00         buchanan  (or burns)    or     disk
#
#    duration (seconds) state_name  state_population  state_military_bases  \
# 0               120.0   Missouri         7474758.0                   2.0
# 1               120.0      Texas        33717239.0                   5.0
# 2                60.0    Indiana         6236667.0                   1.0
# 3                60.0   Illinois        18104498.0                   1.0
# 4                60.0     Oregon         5311863.0                   0.0
#
#    state_cities         day    month  month_number  year_number  season  \
# 0        1020.0  1910-01-01  1910-01             1         1910  winter
# 1        1679.0  1910-06-01  1910-06             6         1910  summer
# 2         677.0  1920-06-11  1920-06             6         1920  summer
# 3        1362.0  1925-12-28  1925-12            12         1925  winter
# 4         373.0  1929-07-05  1929-07             7         1929  summer
#
#    year_season
# 0  1910-winter
# 1  1910-summer
# 2  1920-summer
# 3  1925-winter
# 4  1929-summer

# %%
import re
regex = re.compile(".*?\((.*?)\)")
def strip_string(string):
    result = re.sub("[\(\[].*?[\)\]]", "", string).strip()
    return result

master_state_df['city_cleaned'] = master_state_df['city'].apply(strip_string)

# %%
def value_count_func (series_):
    return len(series_.value_counts())

def most_freq_func (series_):
    x_ = series_.value_counts()
    return list(x_.keys())[0]

def state_season_df (data_, state_):
    
    data_state = data_[data_['state'] == state_]
    
    data_state_season = data_state.groupby(by='year_season').agg({'datetime':'count','duration (seconds)':'mean',
                                          'city':value_count_func,'shape':most_freq_func,'day':value_count_func,
                                          'state_population':'first', 'state_military_bases':'first','state_cities':'first'})
    
    data_state_season.rename(columns={'datetime':'sightings','duration (seconds)':'avg_duration(seconds)',
                                  'city':'sightings_cities','day':'sightings_days'},inplace=True)
    
    data_state_season['state'] = state_
    
    return data_state_season.reset_index().set_index('state')

# %%
STATES_ = list(master_state_df.state.unique()) 
x_ = pd.DataFrame()

for st_ in STATES_:
    
    y_ = state_season_df (master_state_df, st_)
    x_ = pd.concat([x_,y_])
    
x_ = x_.reset_index()

# %%
x_.to_csv('../raw_data/features_by_state_season.csv',header=True,index=False)

# %%
x_
# Out:
#      state  year_season  sightings  avg_duration(seconds)  sightings_cities  \
# 0       mo  1910-winter          1                  120.0                 1
# 1       mo  1947-summer          1                 1140.0                 1
# 2       mo  1950-summer          1                  900.0                 1
# 3       mo  1952-autumn          1                   90.0                 1
# 4       mo  1953-summer          1                  300.0                 1
# ...    ...          ...        ...                    ...               ...
# 8032    dc  2017-spring          1                   60.0                 1
# 8033    dc  2017-winter          1                   60.0                 1
# 8034    dc  2018-autumn          1                  120.0                 1
# 8035    dc  2018-spring          1                  300.0                 1
# 8036    dc  2020-winter          1                 1800.0                 1
#
#           shape  sightings_days  state_population  state_military_bases  \
# 0          disk               1         7474758.0                   2.0
# 1      cylinder               1         7474758.0                   2.0
# 2          disk               1         7474758.0                   2.0
# 3          disk               1         7474758.0                   2.0
# 4      fireball               1         7474758.0                   2.0
# ...         ...             ...               ...                   ...
# 8032     Circle               1         5379184.0                   0.0
# 8033    Unknown               1         5379184.0                   0.0
# 8034  Rectangle               1         5379184.0                   0.0
# 8035       Disk               1         5379184.0                   0.0
# 8036      Light               1         5379184.0                   0.0
#
#       state_cities
# 0           1020.0
# 1           1020.0
# 2           1020.0
# 3           1020.0
# 4           1020.0
# ...            ...
# 8032           1.0
# 8033           1.0
# 8034           1.0
# 8035           1.0
# 8036           1.0
#
# [8037 rows x 10 columns]

# %%
# the features by state season csv
features_df = pd.read_csv('../../raw_data/features_by_state_season.csv', low_memory=False)
features_df.drop(columns= ['state_population', 'state_military_bases', 'state_cities'], inplace = True)
# the population by state season csv
population_df = pd.read_csv('../../raw_data/population_by_state_season.csv', low_memory=False)

#merging the 2 dataframes
merged_df = features_df.merge(population_df, on=['state'], how = 'outer')

# %%
merged_df.to_csv('../../raw_data/merged_df.csv',header=True,index=False)
