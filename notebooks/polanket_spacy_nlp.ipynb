# %%
import spacy

nlp = spacy.load('en_core_web_lg')

# %%
data = pd.read_csv('../raw_data/scrubbed.csv', low_memory=False)
comms = data.comments
data.head(10)
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
# 5  10/10/1961 19:00               bristol    tn      us    sphere
# 6  10/10/1965 21:00    penarth (uk/wales)   NaN      gb    circle
# 7  10/10/1965 23:45               norwalk    ct      us      disk
# 8  10/10/1966 20:00             pell city    al      us      disk
# 9  10/10/1966 21:00              live oak    fl      us      disk
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# ...

# %%
for com in comms:
    print('---------Comment---------')
    doc = nlp(com)
    print(com)
    for token in doc:
        print(f"{token.text} - {token.pos_}") if token.pos_ == 'ADJ' else None
        print(f"{token.text} - {token.dep_}") if token.dep_ == 'nsubj' else None
    print('--------End----------')
# Out:
# ---------Comment---------
# This event took place in early fall around 1949-50. It occurred after a Boy Scout meeting in the Baptist Church. The Baptist Church sit
# event - nsubj
# early - ADJ
# It - nsubj
# Church - nsubj
# --------End----------
# ---------Comment---------
# 1949 Lackland AFB&#44 TX.  Lights racing across the sky &amp; making 90 degree turns on a dime.
# Lights - nsubj
# degree - nsubj
# --------End----------
# ---------Comment---------
# Green/Orange circular disc over Chester&#44 England
# circular - ADJ
# --------End----------
# ---------Comment---------
# My older brother and twin sister were leaving the only Edna theater at about 9 PM&#44...we had our bikes and I took a different route home
# older - ADJ
# brother - nsubj
# twin - ADJ
# only - ADJ
# we - nsubj
# I - nsubj
# different - ADJ
# --------End----------
# ---------Comment---------
# ...
